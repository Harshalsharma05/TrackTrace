# %%
import sys
from pathlib import Path

# Set PROJECT_ROOT to the parent of the 'codes' directory, so 'codes' is importable
PROJECT_ROOT = Path().resolve().parent.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root added:", PROJECT_ROOT)
# Out:
# Project root added: C:\AAA_STUDY\Data Science_ML\Shazam

# %%
file = "one_dance_mic.mp3"

# %%
from codes.app.services.identifier import identify_and_display_redis

identify_and_display_redis(file)
# Out:
# Results: [(3, 17), (4, 1)]
# 🎵 Match found
# Title : One Dance
# Artist: Drake
# Score : 17
